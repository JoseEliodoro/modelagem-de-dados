# %%
import pandas as pd
import os

# %%
df_appearances= pd.read_csv("data/appearances.csv")
df_clubs= pd.read_csv("data/clubs.csv") ###########
df_club_games= pd.read_csv("data/club_games.csv") ###########
df_competitions= pd.read_csv("data/competitions.csv") ###########
df_games= pd.read_csv("data/games.csv") ###########
df_game_events= pd.read_csv("data/game_events.csv") ###########
df_game_lineups= pd.read_csv("data/game_lineups.csv") ###########
df_players= pd.read_csv("data/players.csv") ###########
df_player_valuations= pd.read_csv("data/player_valuations.csv") ###########
df_transfers= pd.read_csv("data/transfers.csv") ###########

# %% [markdown]
# # Tratando os dados de games

# %%
df_games["game_id"].unique().shape
# Out:
# (71513,)

# %%
df_games = df_games.loc[df_games["home_club_id"].isin(df_clubs["club_id"])]
df_games = df_games.loc[df_games["away_club_id"].isin(df_clubs["club_id"])]
df_games = df_games.loc[df_games["competition_id"].isin(df_competitions["competition_id"])]

# %%
df_games["competition_id"].unique().shape, df_competitions["competition_id"].unique().shape
# Out:
# ((43,), (44,))

# %%
df_games.columns
# Out:
# Index(['game_id', 'competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee', 'url',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
df_clubs.loc[df_clubs["club_id"] == 23]
# Out:
#      club_id               club_code                    name  \
# 360       23  eintracht-braunschweig  Eintracht Braunschweig
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# 360                      L1                 NaN          30         25.6
#
#      foreigners_number  foreigners_percentage  national_team_players  \
# 360                 11                   36.7                      2
#
#           stadium_name  stadium_seats net_transfer_record  coach_name  \
# 360  EINTRACHT-Stadion          23325              +€750k         NaN
#
#      last_season                                           filename  \
# 360         2013  ../data/raw/transfermarkt-scraper/2013/clubs.j...
#
#                                                    url
# 360  https://www.transfermarkt.co.uk/eintracht-brau...

# %%
print(df_games.loc[df_games["game_id"] == 2321044]['url'].values)
# Out:
# ['https://www.transfermarkt.co.uk/borussia-dortmund_eintracht-braunschweig/index/spielbericht/2321044']

# %%
columns = [
  'game_id', 
  'competition_id', 
  'season', 
  'round', 
  'date', 
  'home_club_id',   
  'away_club_id', 
  'home_club_goals', 
  'away_club_goals',
  'home_club_manager_name', #tecnico no jogo
  'away_club_manager_name', #tecnico no jogo
  'referee', # arbitro
  'url', 
  'home_club_formation', 
  'away_club_formation',
  'aggregate', # placar
  'competition_type'
]

df_games = df_games[columns]

# %%
df_games
# Out:
#        game_id competition_id  season         round        date  home_club_id  \
# 0      2321044             L1    2013   2. Matchday  2013-08-18            16
# 1      2321060             L1    2013   3. Matchday  2013-08-25            23
# 2      2321086             L1    2013   6. Matchday  2013-09-21             4
# 3      2321152             L1    2013  11. Matchday  2013-11-02            44
# 4      2321205             L1    2013  17. Matchday  2013-12-21            41
# ...        ...            ...     ...           ...         ...           ...
# 71459  3852607            NL1    2022  12. Matchday  2022-10-30           383
# 71460  2589097            NL1    2015  23. Matchday  2016-02-14           467
# 71461  2700827            NL1    2016  23. Matchday  2017-02-18           383
# 71462  3852741            NL1    2022  27. Matchday  2023-04-01           467
# 71463  4097959            NL1    2023   5. Matchday  2023-09-16           383
#
# ...

# %% [markdown]
# # Tratando os dados de competitions

# %%
df_competitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   competition_id            44 non-null     object
#  1   competition_code          44 non-null     object
#  2   name                      44 non-null     object
#  3   sub_type                  44 non-null     object
#  4   type                      44 non-null     object
#  5   country_id                44 non-null     int64
#  6   country_name              36 non-null     object
#  7   domestic_league_code      36 non-null     object
#  8   confederation             44 non-null     object
#  9   url                       44 non-null     object
#  10  is_major_national_league  44 non-null     bool
# dtypes: bool(1), int64(1), object(9)
# memory usage: 3.6+ KB

# %%
df_competitions.columns
# Out:
# Index(['competition_id', 'competition_code', 'name', 'sub_type', 'type',
#        'country_id', 'country_name', 'domestic_league_code', 'confederation',
#        'url', 'is_major_national_league'],
#       dtype='object')

# %%
columns = [
  'competition_id', 
  'competition_code', 
  'name', 
  'sub_type', 
  'type',
  'country_name', 
  'domestic_league_code', 
  'confederation',
  'is_major_national_league']
df_competitions = df_competitions[columns]

# %%
df_competitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   competition_id            44 non-null     object
#  1   competition_code          44 non-null     object
#  2   name                      44 non-null     object
#  3   sub_type                  44 non-null     object
#  4   type                      44 non-null     object
#  5   country_name              36 non-null     object
#  6   domestic_league_code      36 non-null     object
#  7   confederation             44 non-null     object
#  8   is_major_national_league  44 non-null     bool
# dtypes: bool(1), object(8)
# memory usage: 2.9+ KB

# %% [markdown]
# # Tratando os dados de club_games

# %%
df_club_games = df_club_games.loc[df_club_games["club_id"].isin(df_clubs["club_id"])]
df_club_games = df_club_games.loc[df_club_games["game_id"].isin(df_games["game_id"])]
df_club_games = df_club_games.loc[df_club_games["opponent_id"].isin(df_clubs["club_id"])]

# %%
df_club_games["club_id"].unique().shape, df_club_games["opponent_id"].unique().shape
# Out:
# ((439,), (439,))

# %%
df_club_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112616 entries, 3 to 143017
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   game_id                112616 non-null  int64
#  1   club_id                112616 non-null  int64
#  2   own_goals              112616 non-null  int64
#  3   own_position           99364 non-null   float64
#  4   own_manager_name       112260 non-null  object
#  5   opponent_id            112616 non-null  int64
#  6   opponent_goals         112616 non-null  int64
#  7   opponent_position      99364 non-null   float64
#  8   opponent_manager_name  112260 non-null  object
#  9   hosting                112616 non-null  object
#  10  is_win                 112616 non-null  int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 10.3+ MB

# %%
columns = [
  'game_id', 
  'club_id', 
  'opponent_id', 
  'hosting', 
  'is_win'
]
df_club_games[columns]
# Out:
#         game_id  club_id  opponent_id hosting  is_win
# 3       2321044       16           23    Home       1
# 4       2321060       23           24    Home       0
# 5       2321063       33           15    Home       1
# 6       2321086        4           16    Home       0
# 7       2321152       44           33    Home       0
# ...         ...      ...          ...     ...     ...
# 143000  3148382      150          714    Away       0
# 143001  3153158      418          131    Away       0
# 143013  3757977      190          383    Away       0
# 143016  3912646       43          430    Away       0
# 143017  3912662     1177           58    Away       0
#
# [112616 rows x 5 columns]

# %% [markdown]
# # Tratando os dados de clubs

# %%
df_clubs["domestic_competition_id"].unique().shape
# Out:
# (14,)

# %%
df_competitions["competition_id"].unique().shape
# Out:
# (44,)

# %%
df_clubs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  439 non-null    int64
#  1   club_code                439 non-null    object
#  2   name                     439 non-null    object
#  3   domestic_competition_id  439 non-null    object
#  4   total_market_value       0 non-null      float64
#  5   squad_size               439 non-null    int64
#  6   average_age              401 non-null    float64
#  7   foreigners_number        439 non-null    int64
#  8   foreigners_percentage    390 non-null    float64
#  9   national_team_players    439 non-null    int64
#  10  stadium_name             439 non-null    object
#  11  stadium_seats            439 non-null    int64
#  12  net_transfer_record      439 non-null    object
#  13  coach_name               0 non-null      float64
# ...

# %%
df_clubs.loc[df_clubs["name"] == "Ural Yekaterinburg"]
# Out:
#    club_id          club_code                name domestic_competition_id  \
# 1    11127  ural-ekaterinburg  Ural Yekaterinburg                     RU1
#
#    total_market_value  squad_size  average_age  foreigners_number  \
# 1                 NaN          30         26.5                 11
#
#    foreigners_percentage  national_team_players         stadium_name  \
# 1                   36.7                      3  Yekaterinburg Arena
#
#    stadium_seats net_transfer_record  coach_name  last_season  \
# 1          23000              +€880k         NaN         2023
#
#                                             filename  \
# 1  ../data/raw/transfermarkt-scraper/2023/clubs.j...
#
#                                                  url
# 1  https://www.transfermarkt.co.uk/ural-ekaterinb...

# %%
df_clubs.describe()
# Out:
#              club_id  total_market_value  squad_size  average_age  \
# count     439.000000                 0.0  439.000000   401.000000
# mean     6283.476082                 NaN   24.439636    25.526185
# std     14588.760049                 NaN    8.780186     2.010544
# min         3.000000                 NaN    0.000000     0.000000
# 25%       435.500000                 NaN   25.000000    24.600000
# 50%      1158.000000                 NaN   27.000000    25.700000
# 75%      3575.000000                 NaN   29.000000    26.600000
# max    110302.000000                 NaN   41.000000    29.700000
#
#        foreigners_number  foreigners_percentage  national_team_players  \
# count         439.000000             390.000000             439.000000
# mean           11.177677              46.078205               4.749431
# std             6.732010              19.871294               4.913972
# min             0.000000               2.400000               0.000000
# ...

# %%
columns = [
  'club_id', 
  'club_code', 
  'name',
  'domestic_competition_id',
  'squad_size', 
  'average_age',
  'foreigners_number',
  'foreigners_percentage',
  'national_team_players', 
  'stadium_name',
  'stadium_seats', 
  'net_transfer_record',
  'last_season',
]
df_clubs = df_clubs[columns]

# %% [markdown]
# # Tratando os dados de players

# %%
df_players["current_club_id"].unique().shape
# Out:
# (437,)

# %%
df_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32411 entries, 0 to 32410
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             32411 non-null  int64
#  1   first_name                            30353 non-null  object
#  2   last_name                             32411 non-null  object
#  3   name                                  32411 non-null  object
#  4   last_season                           32411 non-null  int64
#  5   current_club_id                       32411 non-null  int64
#  6   player_code                           32411 non-null  object
#  7   country_of_birth                      29622 non-null  object
#  8   city_of_birth                         29964 non-null  object
#  9   country_of_citizenship                32031 non-null  object
#  10  date_of_birth                         32364 non-null  object
# ...

# %%
df_players['agent_name'].unique().shape
# Out:
# (2844,)

# %%
columns = [
  'player_id',
  'first_name',
  'last_name', 
  'name', 
  'last_season',
  'current_club_id',
  'country_of_birth', 
  'city_of_birth',
  'country_of_citizenship',
  'date_of_birth', 
  'sub_position',
  'position',
  'foot', 
  'height_in_cm',
  'contract_expiration_date',
  'current_club_domestic_competition_id',
  'market_value_in_eur',
  'highest_market_value_in_eur'
]
df_players = df_players[columns]

# %% [markdown]
# # Tratando os dados de transfers

# %%
df_transfers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77994 entries, 0 to 77993
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player_id            77994 non-null  int64
#  1   transfer_date        77994 non-null  object
#  2   transfer_season      77994 non-null  object
#  3   from_club_id         77994 non-null  int64
#  4   to_club_id           77994 non-null  int64
#  5   from_club_name       77994 non-null  object
#  6   to_club_name         77994 non-null  object
#  7   transfer_fee         50809 non-null  float64
#  8   market_value_in_eur  48281 non-null  float64
#  9   player_name          77994 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 6.0+ MB

# %%
df_transfers = df_transfers.loc[df_transfers["from_club_id"].isin(df_clubs["club_id"])]
df_transfers = df_transfers.loc[df_transfers["to_club_id"].isin(df_clubs["club_id"])]
df_transfers = df_transfers.loc[df_transfers["player_id"].isin(df_players["player_id"])]

# %%
df_transfers["to_club_id"].unique().shape
# Out:
# (435,)

# %%
df_transfers["from_club_id"].unique().shape
# Out:
# (437,)

# %%
df_clubs["club_id"].unique().shape
# Out:
# (439,)

# %%
df_players["player_id"].unique().shape
# Out:
# (32411,)

# %%
columns = [
  'player_id', 
  'transfer_date', 
  'transfer_season', 
  'from_club_id',
  'to_club_id', 
  'transfer_fee',
  'market_value_in_eur',
]
df_transfers = df_transfers[columns]

# %% [markdown]
# # Tratando os dados de game_events

# %%
df_game_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994931 entries, 0 to 994930
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   game_event_id     994931 non-null  object
#  1   date              994931 non-null  object
#  2   game_id           994931 non-null  int64
#  3   minute            994931 non-null  int64
#  4   type              994931 non-null  object
#  5   club_id           994931 non-null  int64
#  6   player_id         994931 non-null  int64
#  7   description       908869 non-null  object
#  8   player_in_id      475638 non-null  float64
#  9   player_assist_id  151164 non-null  float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 75.9+ MB

# %%
df_game_events["game_id"].unique().shape[0], df_games["game_id"].unique().shape[0]
# Out:
# (71369, 56308)

# %%
df_players["player_id"].unique().shape[0], df_game_events["player_id"].unique().shape[0]
# Out:
# (32411, 62437)

# %%
df_game_events.describe()
# Out:
#             game_id         minute        club_id     player_id  player_in_id  \
# count  9.949310e+05  994931.000000  994931.000000  9.949310e+05  4.756380e+05
# mean   3.184653e+06      61.738129    4985.817284  2.254460e+05  2.704561e+05
# std    6.502105e+05      23.620495   11780.683923  2.050693e+05  2.312098e+05
# min    2.211607e+06      -1.000000       1.000000  1.000000e+01  1.000000e+01
# 25%    2.602701e+06      46.000000     347.000000  6.292000e+04  8.387700e+04
# 50%    3.127383e+06      67.000000     989.000000  1.672640e+05  2.075280e+05
# 75%    3.673495e+06      80.000000    3205.000000  3.310890e+05  3.884650e+05
# max    4.481846e+06     120.000000  122422.000000  1.345257e+06  1.345258e+06
#
#        player_assist_id
# count      1.511640e+05
# mean       2.026693e+05
# std        1.865292e+05
# min        1.000000e+01
# 25%        5.841800e+04
# 50%        1.453775e+05
# 75%        2.927170e+05
# max        1.340495e+06

# %%
df_game_events = df_game_events.loc[df_game_events["game_id"].isin(df_games["game_id"])]
df_game_events = df_game_events.loc[df_game_events["club_id"].isin(df_clubs["club_id"])]
df_game_events = df_game_events.loc[df_game_events["player_id"].isin(df_players["player_id"])]
#df_game_events = df_game_events.loc[df_game_events["player_in_id"].isin(df_players["player_id"])]
#df_game_events = df_game_events.loc[df_game_events["player_assist_id"].isin(df_players["player_id"])]

# %%
df_game_events["game_id"].unique().shape[0], df_games["game_id"].unique().shape[0]
# Out:
# (56218, 56308)

# %%
df_players.loc[df_players["player_id"] == 49499]
# Out:
#       player_id first_name  last_name                 name  last_season  \
# 4263      49499  Georginio  Wijnaldum  Georginio Wijnaldum         2022
#
#       current_club_id country_of_birth city_of_birth country_of_citizenship  \
# 4263               12              NaN     Rotterdam                    NaN
#
#             date_of_birth      sub_position  position   foot  height_in_cm  \
# 4263  1990-11-11 00:00:00  Central Midfield  Midfield  right         175.0
#
#      contract_expiration_date current_club_domestic_competition_id  \
# 4263      2024-06-30 00:00:00                                  IT1
#
#       market_value_in_eur  highest_market_value_in_eur
# 4263            6000000.0                   50000000.0

# %%
df_game_events
# Out:
#                            game_event_id        date  game_id  minute  \
# 0       2f41da30c471492e7d4a984951671677  2012-08-05  2211607      77
# 1       a72f7186d132775f234d3e2f7bc0ed5b  2012-08-05  2211607      77
# 2       b2d721eaed4692a5c59a92323689ef18  2012-08-05  2211607       3
# 3       aef768899cedac0c9a650980219075a2  2012-08-05  2211607      53
# 4       5d6d9533023057b6619ecd145a038bbe  2012-08-05  2211607      74
# ...                                  ...         ...      ...     ...
# 994926  31f3f7ffb104a5f2ea76bb6acf407a67  2024-11-05  4481846      28
# 994927  2e6f7c615ed682d50fc49a86aebf600f  2024-11-05  4481846      69
# 994928  12a25bbf27735d3c24831dd1b7a6b681  2024-11-05  4481846      56
# 994929  2fe434c95e0463c14863798ee6ddf9bf  2024-11-05  4481846      82
# 994930  5d03c6efb2e6a95dc1c803dad0821faa  2024-11-05  4481846      88
#
#                  type  club_id  player_id  \
# 0               Cards      610       4425
# ...

# %%
df_game_events["player_in_id"].unique().shape[0], df_players["player_id"].unique().shape[0]
# Out:
# (23903, 32411)

# %% [markdown]
# # Tratando dados game_lineups

# %%
df_game_lineups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191911 entries, 0 to 2191910
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   game_lineups_id  object
#  1   date             object
#  2   game_id          int64
#  3   player_id        int64
#  4   club_id          int64
#  5   player_name      object
#  6   type             object
#  7   position         object
#  8   number           object
#  9   team_captain     int64
# dtypes: int64(4), object(6)
# memory usage: 167.2+ MB

# %%
df_game_lineups = df_game_lineups.loc[df_game_lineups["game_id"].isin(df_games["game_id"])]
df_game_lineups = df_game_lineups.loc[df_game_lineups["club_id"].isin(df_clubs["club_id"])]
df_game_lineups = df_game_lineups.loc[df_game_lineups["player_id"].isin(df_players["player_id"])]

# %% [markdown]
# # Tratando dados de player_valuations

# %%
df_player_valuations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487946 entries, 0 to 487945
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   player_id                            487946 non-null  int64
#  1   date                                 487946 non-null  object
#  2   market_value_in_eur                  487946 non-null  int64
#  3   current_club_id                      487946 non-null  int64
#  4   player_club_domestic_competition_id  487946 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 18.6+ MB

# %%
df_player_valuations
# Out:
#         player_id        date  market_value_in_eur  current_club_id  \
# 0          405973  2000-01-20               150000             3057
# 1          342216  2001-07-20               100000             1241
# 2            3132  2003-12-09               400000              126
# 3            6893  2003-12-15               900000              984
# 4              10  2004-10-04              7000000              398
# ...           ...         ...                  ...              ...
# 487941    1083164  2024-10-18              1000000              252
# 487942    1110645  2024-10-18               500000              398
# 487943    1144700  2024-10-18              4000000              430
# 487944     746973  2024-11-06                50000              234
# 487945     715382  2024-11-22               100000             1083
#
#        player_club_domestic_competition_id
# 0                                      BE1
# 1                                      SC1
# ...

# %%
df_player_valuations = df_player_valuations.loc[df_player_valuations["player_id"].isin(df_players["player_id"])]
df_player_valuations = df_player_valuations.loc[df_player_valuations["player_id"].isin(df_clubs["club_id"])]

# %% [markdown]
# # Tratando dados de appearances

# %%
df_appearances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1643450 entries, 0 to 1643449
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   appearance_id           1643450 non-null  object
#  1   game_id                 1643450 non-null  int64
#  2   player_id               1643450 non-null  int64
#  3   player_club_id          1643450 non-null  int64
#  4   player_current_club_id  1643450 non-null  int64
#  5   date                    1643450 non-null  object
#  6   player_name             1643444 non-null  object
#  7   competition_id          1643450 non-null  object
#  8   yellow_cards            1643450 non-null  int64
#  9   red_cards               1643450 non-null  int64
#  10  goals                   1643450 non-null  int64
#  11  assists                 1643450 non-null  int64
#  12  minutes_played          1643450 non-null  int64
# dtypes: int64(9), object(4)
# ...

# %%
df_appearances.loc[df_appearances["player_id"] == 38004]
# Out:
#         appearance_id  game_id  player_id  player_club_id  \
# 0       2231978_38004  2231978      38004             853
# 52      2231980_38004  2231980      38004             853
# 507     2244350_38004  2244350      38004             853
# 1303    2244351_38004  2244351      38004             853
# 2431    2246629_38004  2246629      38004             853
# ...               ...      ...        ...             ...
# 240991  2342532_38004  2342532      38004             235
# 241851  2342505_38004  2342505      38004             235
# 244316  2342554_38004  2342554      38004             235
# 247518  2342540_38004  2342540      38004             235
# 253668  2342548_38004  2342548      38004             235
#
#         player_current_club_id        date       player_name competition_id  \
# 0                          235  2012-07-03  Aurélien Joachim            CLQ
# 52                         235  2012-07-10  Aurélien Joachim            CLQ
# ...

# %%
df_appearances = df_appearances.loc[df_appearances["competition_id"].isin(df_competitions["competition_id"])]
df_appearances = df_appearances.loc[df_appearances["player_id"].isin(df_players["player_id"])]
df_appearances = df_appearances.loc[df_appearances["player_club_id"].isin(df_clubs["club_id"])]
df_appearances = df_appearances.loc[df_appearances["player_current_club_id"].isin(df_clubs["club_id"])]
df_appearances = df_appearances.loc[df_appearances["game_id"].isin(df_games["game_id"])]

# %%
columns = [
  'appearance_id', 
  'game_id', 
  'player_id',
  'player_club_id',
  'player_current_club_id',
  'date',
  'competition_id',
  'yellow_cards', 
  'red_cards',
  'goals', 
  'assists', 
  'minutes_played'
]
df_appearances = df_appearances[columns]

# %%
df_appearances.to_csv("data-new/appearances.csv", index=False)
df_clubs.to_csv("data-new/clubs.csv", index=False)
df_club_games.to_csv("data-new/club_games.csv", index=False)
df_competitions.to_csv("data-new/competitions.csv", index=False)
df_games.to_csv("data-new/games.csv", index=False)
df_game_events.to_csv("data-new/game_events.csv", index=False)
df_game_lineups.to_csv("data-new/game_lineups.csv", index=False)
df_players.to_csv("data-new/players.csv", index=False)
df_player_valuations.to_csv("data-new/player_valuations.csv", index=False)
df_transfers.to_csv("data-new/transfers.csv", index=False)
